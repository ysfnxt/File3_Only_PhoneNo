# %%
import pandas as pd

# %%
df = pd.read_csv("file3_phoneonly.csv")

# %%
df
# Out:
#                 full name first_name  last_name
# 0        charnie guttmann    charnie   guttmann  \
# 1         colleen pinkham    colleen    pinkham
# 2            vicki finley      vicki     finley
# 3         michael brinton    michael    brinton
# 4          marsha auguste     marsha    auguste
# ...                   ...        ...        ...
# 4312839    marcielle wray  marcielle       wray
# 4312840   robert browning     robert   browning
# 4312841    jenny boughner      jenny   boughner
# 4312842    david chandler      david   chandler
# 4312843  andrea goldstein     andrea  goldstein
#
#                                         linkedin_url
# 0          linkedin.com/in/charnie-guttmann-6301b313  \
# 1           linkedin.com/in/colleen-pinkham-542b1941
# 2               linkedin.com/in/vicki-finley-8706079
# 3           linkedin.com/in/michael-brinton-14bb4525
# 4             linkedin.com/in/marsha-auguste-5057246
# ...                                              ...
# ...

# %%
len(df["phone_numbers"])
# Out:
# 4312844

# %%
len(df["phone_numbers"].unique())
# Out:
# 2483308

# %%
# Removed duplicated phone numbers 
df.drop_duplicates(subset=["phone_numbers"], keep='first')
# Out:
#                  full name first_name last_name
# 0         charnie guttmann    charnie  guttmann  \
# 1          colleen pinkham    colleen   pinkham
# 2             vicki finley      vicki    finley
# 3          michael brinton    michael   brinton
# 4           marsha auguste     marsha   auguste
# ...                    ...        ...       ...
# 3674941         rod burris        rod    burris
# 3674945     jenny boughner      jenny  boughner
# 3674946     david chandler      david  chandler
# 4061219  kristina ippolito   kristina  ippolito
# 4061220       sarah solari      sarah    solari
#
#                                         linkedin_url
# 0          linkedin.com/in/charnie-guttmann-6301b313  \
# 1           linkedin.com/in/colleen-pinkham-542b1941
# 2               linkedin.com/in/vicki-finley-8706079
# 3           linkedin.com/in/michael-brinton-14bb4525
# 4             linkedin.com/in/marsha-auguste-5057246
# ...                                              ...
# ...

# %%
df.to_csv("file3_dup_removed.csv")
